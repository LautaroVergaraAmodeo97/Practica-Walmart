# %% [markdown]
# En este paso vamos a realizar los gráficos que más nos interesa a nosotros para poder trabajar.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:\\Users\\User\\OneDrive\\Escritorio\\Proyecto Walmart\\Proyecto_Walmart\\ETL\\dataset_limpio.csv')

# %% [markdown]
# Datos de la columnas
#
# - Date (junto a Year,Month,Day,Hour) 📅 - El día de negociación registrado.
# - Open 🟢 - Precio de apertura del mercado.
# - High 🔼 - Precio más alto del día.
# - Low🔽 - Precio mínimo del día.
# - Close 🔴 - Precio al cierre del mercado.
# - Volume 📈 – Total de acciones negociadas.
# - Dividends 💰 - Pagos en efectivo a los accionistas.
# - Stock Splits 🔄 - Registra las divisiones de acciones.

# %% [markdown]
# Ahora vamos a realizar un promedio de cierre (Close) por cada año y vamos a graficar en un plot lineal.

# %%
promedio_cierre = df.groupby('Year')['Close'].mean().reset_index()

promedio_cierre
# Out:
#     Year      Close
# 0   1972   0.011430
# 1   1973   0.007898
# 2   1974   0.005449
# 3   1975   0.007892
# 4   1976   0.010397
# 5   1977   0.011011
# 6   1978   0.016582
# 7   1979   0.020431
# 8   1980   0.031028
# 9   1981   0.055756
# 10  1982   0.091549
# 11  1983   0.217303
# 12  1984   0.238088
# 13  1985   0.313090
# 14  1986   0.529048
# 15  1987   0.764355
# 16  1988   0.747789
# 17  1989   0.970145
# 18  1990   1.373265
# 19  1991   2.223353
# 20  1992   2.903050
# 21  1993   2.871544
# 22  1994   2.558973
# 23  1995   2.540647
# 24  1996   2.565400
# 25  1997   3.446633
# 26  1998   6.228087
# 27  1999  10.409446
# 28  2000  11.556054
# 29  2001  11.244266
# 30  2002  12.037565
# 31  2003  11.878818
# 32  2004  12.108749
# 33  2005  10.863989
# 34  2006  10.536916
# 35  2007  10.782030
# 36  2008  12.886346
# 37  2009  12.065247
# 38  2010  12.930116
# 39  2011  13.597044
# 40  2012  17.267315
# 41  2013  19.813634
# 42  2014  20.849433
# 43  2015  20.012577
# ...

# %%
#Configuramos el plot
fig,ax = plt.subplots(figsize=(6,4))

sns.lineplot(x=promedio_cierre['Year'],y=promedio_cierre['Close'],data=promedio_cierre)

plt.xlabel('Año')
plt.ylabel('Promedio de cierre')
plt.title('Cierre de acciones por cada año')
plt.show()

# %% [markdown]
# Ahora vamos a hacer un gráfico de barras pero de los ultimos 5 años (2020-2025)

# %%
ultimos_5_años = promedio_cierre.tail(5)

ultimos_5_años
# Out:
#     Year      Close
# 49  2021  44.881285
# 50  2022  44.480829
# 51  2023  50.043651
# 52  2024  69.920324
# 53  2025  96.859706

# %%
#Configuramos el plot
fig,ax = plt.subplots(figsize=(6,4))

sns.barplot(data=ultimos_5_años,x=ultimos_5_años['Year'],y=ultimos_5_años['Close'])

plt.xlabel('Año')
plt.ylabel('Promedio de cierre')
plt.title('Cierre de acciones por cada año')
plt.show()

# %% [markdown]
# La primera observación que podemos notar es que 2021 y 2022 están practicamente igualado. Esto es debido a post pandemia de COVID 19 y que el gobierno de turno estadounidense no creció en esos años.

# %% [markdown]
# Ahora vamos a realizar un histograma de los precios de cierre de los últimos 5 años.

# %%
#Configuramos el plot
fig,ax = plt.subplots(figsize=(15,6))

sns.histplot(data=promedio_cierre,x=promedio_cierre['Year'],y=promedio_cierre['Close'],bins=5)

plt.xlabel('Año')
plt.ylabel('Promedio de cierre')
plt.title('Cierre de acciones por cada año')
plt.show()

# %%
promedio_apertura = df.groupby('Year')['Open'].mean().reset_index()

# %%
promedio_acciones = df.groupby('Year')['Volume'].mean().reset_index()

promedio_acciones = promedio_acciones.tail(5)

promedio_acciones
# Out:
#     Year        Volume
# 49  2021  2.497727e+07
# 50  2022  2.390431e+07
# 51  2023  1.894174e+07
# 52  2024  1.699067e+07
# 53  2025  1.692026e+07

# %%
#Configuramos el plot
fig,ax = plt.subplots(figsize=(15,6))

sns.barplot(data=promedio_acciones,x=promedio_acciones['Year'],y=promedio_acciones['Volume'])

plt.xlabel('Año')
plt.ylabel('Promedio de acciones')
plt.title('Cierre de acciones por cada año')
plt.show()

# %% [markdown]
# Se puede ver la baja de acciones que sufrio la empresa Walmart. Inversamente proporciona a los precios de cierre.
